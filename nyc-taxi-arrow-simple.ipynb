# %%
import coiled
from dask.distributed import wait 
import dask.dataframe as dd 
import dask

# %% [markdown]
# ### With Arrow strings

# %%
dask.config.set({"dataframe.convert-string": True})

# %%
# %%time

cluster = coiled.Cluster( 
    n_workers=15,
    backend_options={"region": "us-east-2"},
)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CPU times: user 4.88 s, sys: 407 ms, total: 5.29 s
# Wall time: 1min 10s

# %%
# %%time

client = cluster.get_client()
client
# Out:
# CPU times: user 15.3 ms, sys: 4.72 ms, total: 20 ms
# Wall time: 533 ms
# <Client: 'tls://10.0.23.181:8786' processes=15 threads=60, memory=224.07 GiB>

# %%
# %%time

df = dd.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    storage_options={"anon": True},
).persist()

wait(df);
# Out:
# CPU times: user 621 ms, sys: 165 ms, total: 786 ms
# Wall time: 30.9 s

# %% [markdown]
# ### With object strings

# %%
# %%time

client.restart()
# Out:
# CPU times: user 20.2 ms, sys: 5.99 ms, total: 26.2 ms
# Wall time: 4.01 s
# <Client: 'tls://10.0.20.68:8786' processes=14 threads=56, memory=209.11 GiB>

# %%
dask.config.set({"dataframe.convert-string": False})

# %%
# %%time

cluster.scale(45)
client.wait_for_workers(45)
# Out:
# CPU times: user 1.09 s, sys: 282 ms, total: 1.37 s
# Wall time: 1min 15s

# %%
# %%time

df = dd.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    storage_options={"anon": True},
).persist()

wait(df);
# Out:
# CPU times: user 632 ms, sys: 170 ms, total: 802 ms
# Wall time: 33.7 s

# %%
client.close()

# %%
cluster.close()
