# %%
import coiled
from dask.distributed import wait 
import dask.dataframe as dd 
import dask
from dask.utils import format_bytes

# %% [markdown]
# ### With object strings

# %%
dask.config.set({"dataframe.convert-string": False})

# %%
# %%time

cluster = coiled.Cluster(
    name="lightning-demo-2",
    n_workers=45,
    backend_options={"region": "us-east-2"},
    scheduler_options={"idle_timeout": "2 hours"},
)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CPU times: user 4.77 s, sys: 510 ms, total: 5.28 s
# Wall time: 1min 39s

# %%
# %%time

cluster = coiled.Cluster(name="lightning-demo-2")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()

# %%
# %%time

client = cluster.get_client()
client
# Out:
# CPU times: user 57 µs, sys: 1e+03 ns, total: 58 µs
# Wall time: 63.2 µs
# <Client: 'tls://10.0.24.92:8786' processes=43 threads=172, memory=642.06 GiB>

# %%
# %%time

df = dd.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    storage_options={"anon": True},
).persist()

wait(df);
# Out:
# CPU times: user 704 ms, sys: 234 ms, total: 938 ms
# Wall time: 32.3 s

# %%
df.memory_usage(deep=True).compute().sum().apply(format_bytes)

# %%
client.close()

# %%
cluster.close()
